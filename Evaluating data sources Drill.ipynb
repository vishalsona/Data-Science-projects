# %% [markdown]
# In each of the scenarios, find possible shortcomings of the data sources to answer the given question. What could be done to either adjust the analysis or reframe the question so that you can answer it accurately?
#
# **Data Source:** Amsterdam availability data scraped from AirBnB on December 24th. Question: What are the popular neighborhoods in Amsterdam?
#
# **Answer**
#
# **_Shortcomings:_** The Dataset has been collected on the Christmas Eve means it will come under exceptional circumstance.
#
# **_Correction:_** More accurate question can be "What are the popular neighborhood in Amsterdam during Chrismas?"
#
# **Data Source:** Mental health services use on September 12, 2001 in San Francisco, CA and New York City, NY. Question: How do patterns of mental health service use vary between cities?
#
# **Answer**
#
# **_Shortcomings:_** The dataset taken is of the next day of very important day 9/11 of the history. Entire country was in shock specially New York city as they have wintnessed most distubing event. Hence mental service use between two cities would not be accurate.
#
# **_Correction:_** The question should be "How do patterns of mental health service use vary between cities after terrorist attack and one city being the victim.
#
# **Data Source:** Armenian Pub Survey. Question: What are the most common reasons Armenians visit local pubs?
#
# **Answer**
# _This dataset looks good to me. we can get the answer of the question asked._

# %%
import pandas as pd
import numpy as np
import statistics as stat

df = pd.read_csv('armenian_pubs.csv')
df
# Out:
#                         Timestamp  Age  Gender    Income          Occupation  \
# 0    2017/02/25 10:52:03 PM GMT+4    19    Male  100000.0            Student
# 1    2017/02/25 10:53:19 PM GMT+4    19  Female   50000.0            Student
# 2    2017/02/25 10:54:05 PM GMT+4    20    Male  100000.0            Student
# 3    2017/02/25 10:55:09 PM GMT+4    18    Male       0.0            Student
# 4    2017/02/25 10:55:38 PM GMT+4    19  Female  130000.0  Student + working
# 5    2017/02/25 10:55:39 PM GMT+4    19    Male   90000.0            Student
# 6    2017/02/25 10:55:41 PM GMT+4    18  Female       0.0            Student
# 7    2017/02/25 10:55:45 PM GMT+4    19  Female       0.0            Student
# 8    2017/02/25 10:56:17 PM GMT+4    19    Male   80000.0  Student + working
# 9    2017/02/25 10:56:45 PM GMT+4    19    Male  150000.0            Student
# 10   2017/02/25 10:56:52 PM GMT+4    20  Female   80000.0            Student
# ...

# %%
df['Occasions']
# Out:
# 0          Hang outs with friends
# 1          Hang outs with friends
# 2          Hang outs with friends
# 3          Hang outs with friends
# 4          Hang outs with friends
# 5          Hang outs with friends
# 6          Hang outs with friends
# 7          Hang outs with friends
# 8          Hang outs with friends
# 9          Hang outs with friends
# 10         Special events/parties
# 11         Hang outs with friends
# 12         Hang outs with friends
# 13         Special events/parties
# 14         Hang outs with friends
# 15         Hang outs with friends
# 16         Hang outs with friends
# 17                      Birthdays
# 18         Hang outs with friends
# 19                      Birthdays
# 20         Hang outs with friends
# 21         Hang outs with friends
# 22         Hang outs with friends
# 23         Hang outs with friends
# 24         Hang outs with friends
# 25         Hang outs with friends
# 26         Hang outs with friends
# ...

# %%
stat.mode(df['Occasions'])
# Out:
# 'Hang outs with friends'
